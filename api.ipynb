# %%
import requests
import json

# %%
api_key='25d6caf3b7e5d9c3cd3542e887a831c9'
lat=float(input("Latitude?? "))
lon=float(input("Longitude?? "))
# Out:
# Latitude?? 33
# Longitude?? 139

# %%
url="https://api.openweathermap.org/data/2.5/onecall?lat={lat}&lon={lon}&exclude={part}&appid={YOUR_API_KEY}\
".format(lon=lon, lat=lat, part='minutely',YOUR_API_KEY=api_key)

r=requests.get(url)

# %%
r.text
# Out:
# '{"lat":33,"lon":139,"timezone":"Asia/Tokyo","timezone_offset":32400,"current":{"dt":1593824410,"sunrise":1593805209,"sunset":1593856578,"temp":299.6,"feels_like":297.82,"pressure":1011,"humidity":86,"dew_point":297.07,"uvi":12.68,"clouds":100,"wind_speed":10.78,"wind_deg":218,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}],"rain":{"1h":0.5}},"hourly":[{"dt":1593824400,"temp":299.6,"feels_like":297.82,"pressure":1011,"humidity":86,"dew_point":297.07,"clouds":100,"wind_speed":10.78,"wind_deg":218,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}],"rain":{"1h":0.5}},{"dt":1593828000,"temp":299.7,"feels_like":298.16,"pressure":1011,"humidity":86,"dew_point":297.16,"clouds":100,"wind_speed":10.52,"wind_deg":221,"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}],"rain":{"1h":0.81}},{"dt":1593831600,"temp":299.8,"feels_like":298.54,"pressure":1010,"humidity":85,"dew_point":297.07,"clouds":100,"wind_speed":10.0
# ...
